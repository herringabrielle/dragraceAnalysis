# %% [markdown]
# 2019-10-12T18:21:15Z

# %%
import obspy
import numpy as np
import math
import cmath
import serveobspy
from obspy import UTCDateTime, read, Trace, Stream
import dragrace
import SeismogramTasks as sTasks
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import matplotlib
# %matplotlib inline

# %%
serveSeis = serveobspy.ServeObsPy('www')
serveSeis.serveData()
# Out:
# http server started at http://127.0.0.1:8000
# websocket server started ws://127.0.0.1:8001
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "//anaconda3/envs/obspy/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/gabby/Desktop/dragraceAnalysis-master/serveobspy.py", line 399, in run
#     httpd = server_class(server_address, self.handler_class)
#   File "//anaconda3/envs/obspy/lib/python3.7/socketserver.py", line 452, in __init__
#     self.server_bind()
#   File "//anaconda3/envs/obspy/lib/python3.7/http/server.py", line 137, in server_bind
#     socketserver.TCPServer.server_bind(self)
#   File "//anaconda3/envs/obspy/lib/python3.7/socketserver.py", line 466, in server_bind
#     self.socket.bind(self.server_address)
# OSError: [Errno 48] Address already in use
#
# Exception in thread Thread-46:
# Traceback (most recent call last):
#   File "//anaconda3/envs/obspy/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/Users/gabby/Desktop/dragraceAnalysis-master/serveobspy.py", line 496, in run
#     asyncio.get_event_loop().run_until_complete(asyncio.ensure_future(self.initWS()))
#   File "//anaconda3/envs/obspy/lib/python3.7/asyncio/base_events.py", line 584, in run_until_complete
#     return future.result()
#   File "/Users/gabby/Desktop/dragraceAnalysis-master/serveobspy.py", line 491, in initWS
#     self.server = await websockets.serve(handler, self.host, self.port)
#   File "//anaconda3/envs/obspy/lib/python3.7/site-packages/websockets/server.py", line 965, in __await_impl__
#     server = await self._create_server()
#   File "//anaconda3/envs/obspy/lib/python3.7/asyncio/base_events.py", line 1378, in create_server
#     % (sa, err.strerror.lower())) from None
# OSError: [Errno 48] error while attempting to bind on address ('127.0.0.1', 8001): address already in use
#
# 127.0.0.1 - - [16/Apr/2020 09:42:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:42:35] "GET /obspyconnection.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:42:35] "GET /viewObspy.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:42:35] "GET /tools.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:42:36] "GET /dataset HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:42:36] "GET /seismograms/4743369672/stats HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:42:36] "GET /seismograms/4743369672/mseed HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:45:31] "GET /dataset HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:45:31] "GET /seismograms/4743369672/mseed HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:45:31] "GET /seismograms/4743369672/stats HTTP/1.1" 200 -

# %% [markdown]
# This is a Top Fuel Race Q3 Heat 5 in Fall 2019 that showed large ground acceleration at the station NL especially in the X component.

# %%
start = '2019-10-12T18:21:15Z' # FALL Winning race TF Q3 Heat 5

# %%
from obspy import read
# FL NL NR FR
stx = read("./fallClean/Corrected/FAr_FL_2019-10-12T18:21:15Z_HNX.mseed")
sty = read("./fallClean/Corrected/FAr_FL_2019-10-12T18:21:15Z_HNY.mseed")
stz = read("./fallClean/Corrected/FAr_FL_2019-10-12T18:21:15Z_HNZ.mseed")

# %%
serveSeis.stream=stx
serveSeis.title="Top Fuel Q3 Heat 5 Winning Race FL"
# Out:
# 127.0.0.1 - - [16/Apr/2020 09:55:33] "GET / HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Apr/2020 09:55:33] "GET /obspyconnection.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Apr/2020 09:55:33] "GET /viewObspy.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Apr/2020 09:55:33] "GET /tools.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Apr/2020 09:55:34] "GET /dataset HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:55:34] "GET /seismograms/4743369672/mseed HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:55:34] "GET /seismograms/4743369672/stats HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:55:48] "GET / HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Apr/2020 09:55:48] "GET /obspyconnection.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Apr/2020 09:55:48] "GET /viewObspy.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Apr/2020 09:55:48] "GET /tools.js HTTP/1.1" 304 -
# 127.0.0.1 - - [16/Apr/2020 09:55:49] "GET /dataset HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:55:49] "GET /seismograms/4743369672/mseed HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 09:55:49] "GET /seismograms/4743369672/stats HTTP/1.1" 200 -

# %% [markdown]
# Convert data from Counts to g using conversion factor
# Repopulate Obspy Stream with Stats

# %%
# create a new empty trace
stg = Stream([Trace()])

# conversion factor
gravity = 4096

# make stream a list to apply conversion factor
stList = st[0].data.tolist()
gData = []

for value in stList:
    gData.append(value/gravity)

# obspy likes numpy arrays
numpyList= np.asarray(gData, dtype=np.float32) 

# new obspy stream with amp values in g
stg[0].data = numpyList


# update the stats
stg[0].stats['starttime'] = '2019-10-12T18:21:05.002500Z'
stg[0].stats['delta'] = '0.005'
stg[0].stats['sampling_rate'] = '200.0'
stg[0].stats['network'] = 'XX'
stg[0].stats['station'] = 'NL'
stg[0].stats['channel'] = 'HNX'
stg[0].stats['location'] = 'zMAX'
#print(stg[0].stats)

# %% [markdown]
# 1. Plot the Data in Jupyter Notebook
# Issues : Obspy has a fancy time domain, I will fix it later but for now Time is not plotted as Time but rather as index.

# %%
# Plot using matplot lib

#create figure
fig = plt.figure(figsize=(50, 10))
data = stg[0].data

start = stg[0].stats['starttime']
delta = stg[0].stats['delta']
end = stg[0].stats['endtime']
#print(start) 

# plot and label graph
plt.plot(data)
plt.title('Top Fuel Race Q3 Heat 5 Fall 2019', fontsize = 30)
plt.xlabel('2019-10-12T18:21:05.002500Z - 2019-10-12T18:22:04.997500Z (delta = 0.005 s)', fontsize = 30)
plt.ylabel('Ground Acceleration (g)', fontsize = 30)
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 30)
plt.show()
# Out:
# 2019-10-12T18:21:05.002500Z

# %% [markdown]
# 2. Apply 3 point moving average FIR filter
