# %%
import obspy
import numpy
import math
import cmath
from obspy import UTCDateTime, read, Trace, Stream
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import matplotlib
# %matplotlib inline
import scipy

from scipy import signal
from matplotlib import patches
from matplotlib.pyplot import axvline, axhline
import obspy

# %%
from obspy import read

stFL0 = read("./FallClean/Corrected/FAr_FL0_2019-10-12T21:44:29Z_HNZ.mseed")
stFL = read("./FallClean/Corrected/FAr_FL_2019-10-12T21:44:29Z_HNZ.mseed")
stFL60 = read("./FallClean/Corrected/FAr_FL60_2019-10-12T21:44:29Z_HNZ.mseed")
stFL330 = read("./FallClean/Corrected/FAr_FL330_2019-10-12T21:44:29Z_HNZ.mseed")
stFL660 = read("./FallClean/Corrected/FAr_FL660_2019-10-12T21:44:29Z_HNZ.mseed")
stFL1K = read("./FallClean/Corrected/FAr_FL1K_2019-10-12T21:44:29Z_HNZ.mseed")

start = st[0].stats['starttime']
print(start)
#sta = 'FL660'
comp = 'Z'
npts = st[0].stats['npts']
# Out:
# 2019-10-12T21:44:19.001200Z

# %%
def gData(sta,comp,start,st): # st must be an obspy stream

    # create a new empty trace
    stg = Stream([Trace()])

    # conversion factor
    gravity = 4096
    
    # 
    data = st[0].data
    
    # make stream a list to apply conversion factor
    stList = data.tolist()
    #stList = st[0].data.tolist()
    gData = []

    for value in stList:
        gData.append(value/gravity)
    # obspy likes numpy arrays
    numpyList= np.asarray(gData, dtype=np.float32)
    
    # new obspy stream with amp values in g
    stg[0].data = numpyList


    # update the stats
    stg[0].stats['starttime'] = start
    stg[0].stats['delta'] = '0.005'
    stg[0].stats['sampling_rate'] = '200.0'
    stg[0].stats['network'] = 'XX'
    stg[0].stats['station'] = sta
    stg[0].stats['channel'] = comp
    stg[0].stats['location'] = 'zMAX'
    print(stg[0].stats)
    return stg

# %%
from datetime import datetime, timedelta
import pandas as pd

def mkTime(i,f,stg):#i = index to start with, f = index to end with, default with i=0 and f = npts
    # make some variables
    startSTZ = stg[0].stats['starttime']
    deltaSTZ = stg[0].stats['delta']
    nptSTZ = stg[0].stats['npts']
    
    # convert to a understandable string time format
    startSTZ = str(startSTZ)
    endSTZ = str(stg[0].stats['endtime'])
    startSTZ = datetime.strptime(startSTZ, '%Y-%m-%dT%H:%M:%S.%fZ')
    endSTZ = datetime.strptime(endSTZ, '%Y-%m-%dT%H:%M:%S.%fZ')
    
    # use the given start and stop times
    idxStart = i
    idxEnd = f
    timeStart = deltaSTZ * idxStart # START TIME IS FIRST INDEX
    #print('timeStart',timeStart)
    timeEnd = deltaSTZ * idxEnd # ENDTIME IS LAST INDEX

    # make into a time 
    st = pd.Timestamp(startSTZ+timedelta(seconds=timeStart)) # This was more complicated than it needs to be
    fin = pd.Timestamp(startSTZ+timedelta(seconds=timeEnd))

    # Put into equally spaced domain
    timeDomain = np.linspace(st.value,fin.value,nptSTZ)
    timeDomain = pd.to_datetime(timeDomain)
    
    # return the time Domain list
    print(len(timeDomain))
    return timeDomain

# %%
# convert to g
#stg = gData(sta,comp,start)
stFL0 = gData('FL0',comp,start,stFL0)
stFL = gData('FL',comp,start,stFL)
stFL60 = gData('FL60',comp,start,stFL60)
stFL330 = gData('FL330',comp,start,stFL330)
stFL660 = gData('FL660',comp,start,stFL660)
stFL1K = gData('FL1K',comp,start,stFL1K)


# make time domain
i = 0
f = npts
timeDomain = mkTime(i,f,stFL)
print(timeDomain)
# Out:
#          network: XX
#          station: FL0
#         location: zMAX
#          channel: Z
#        starttime: 2019-10-12T21:44:19.001200Z
#          endtime: 2019-10-12T21:45:19.001200Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 12001
#            calib: 1.0
#          network: XX
#          station: FL
#         location: zMAX
#          channel: Z
#        starttime: 2019-10-12T21:44:19.001200Z
#          endtime: 2019-10-12T21:45:19.001200Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 12001
#            calib: 1.0
#          network: XX
#          station: FL60
#         location: zMAX
#          channel: Z
#        starttime: 2019-10-12T21:44:19.001200Z
#          endtime: 2019-10-12T21:45:19.001200Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 12001
#            calib: 1.0
#          network: XX
#          station: FL330
#         location: zMAX
#          channel: Z
# ...

# %%
def posStream(st, pos):
    data = st[0].data
    
    # make stream a list to apply conversion factor
    stList = data.tolist()
    #stList = st[0].data.tolist()
    newData = []

    for value in stList:
        newData.append(250*value + pos)
    # obspy likes numpy arrays
    numpyList= np.asarray(newData, dtype=np.float32)

    # new obspy stream with amp values in g
    st[0].data = numpyList
    return st[0].data

# %%
print(stFL660[0].data[10])
#print(stFL0[0].data[10])
for sta in ['FL0','FL','FL60','FL330','FL660','FL1K']:
    if sta == 'FL0':
        posStream(stFL0, -24)
    if sta == 'FL':
        posStream(stFL, 0)
    if sta == 'FL60':
        posStream(stFL60, 60)
    if sta == 'FL330':
        posStream(stFL330, 330)
    if sta == 'FL660':
        posStream(stFL660, 660)
    if sta == 'FL1K':
        posStream(stFL1K, 1000)
        
print(stFL660[0].data[10])
# Out:
# -0.00989139
# 657.527

# %%
FL0 = 48.082
FL = 48.125
FL60 = 48.152
FL330 = 48.396
FL660 = 48.650
FL1K = 49.036
staTime = [48.082, 48.125, 48.152, 48.396, 48.650, 49.036] 
staPos = [-24, 0, 60, 330, 660, 1000]

# Find Line of Best FIT
x = staPos
y = staTime
m, b = np.polyfit(x, y, 1)
print(m,b)

bestFit = []
for i in staPos:
    bestFit.append(m * i + b)
print(bestFit)



bestFitLine = ['2019-10-12 21:44:48.081132259445035', '2019-10-12 21:44:48.102745602597068', '2019-10-12 21:44:48.156778960477155', '2019-10-12 21:44:48.399929070937546', '2019-10-12 21:44:48.697112539278024', '2019-10-12 21:44:49.003301567265183']
# Out:
# 0.000900555964668 48.1027456026
# [48.081132259445035, 48.102745602597068, 48.156778960477155, 48.399929070937546, 48.697112539278024, 49.003301567265183]

# %%
x1=5600
x2=7200

fig = plt.figure(figsize=(30, 15))
plt.plot(stFL0[0].data[x1:x2],timeDomain[x1:x2],color = 'k')
plt.plot(stFL[0].data[x1:x2],timeDomain[x1:x2],color = 'k')
plt.plot(stFL60[0].data[x1:x2],timeDomain[x1:x2],color = 'k')
plt.plot(stFL330[0].data[x1:x2],timeDomain[x1:x2],color = 'k')
plt.plot(stFL660[0].data[x1:x2],timeDomain[x1:x2],color = 'k')
plt.plot(stFL1K[0].data[x1:x2],timeDomain[x1:x2],color = 'k')

firstPick = '2019-10-12 21:44:48.082'
xmin = stFL0[0].data[x1]
xmax = stFL1K[0].data[x1]
plt.hlines(pd.to_datetime(firstPick),xmin, xmax, color = 'b', label = 'First Arrival Time',linewidth = 2.0)

FL0 = '2019-10-12 21:44:48.082'
FL = '2019-10-12 21:44:48.125'
FL60 = '2019-10-12 21:44:48.152'
FL330 = '2019-10-12 21:44:48.396'
FL660 = '2019-10-12 21:44:48.650'
FL1K = '2019-10-12 21:44:49.036'

staList = [FL0,FL,FL60,FL330,FL660,FL1K]
yList = [pd.to_datetime(FL0),pd.to_datetime(FL),pd.to_datetime(FL60), pd.to_datetime(FL330), pd.to_datetime(FL660),pd.to_datetime(FL1K)]
xList = [stFL0[0].data[x1],stFL[0].data[x1],stFL60[0].data[x1],stFL330[0].data[x1],stFL660[0].data[x1],stFL1K[0].data[x1]]
#plt.plot(xList,yList,color = 'r',linewidth = 2.0)

# Best Fit Linear
plt.plot(xList, pd.to_datetime(bestFitLine), color = 'C1',linewidth = 2.0, label = 'Best Fit deg = 1')


plt.legend(loc = 'upper center', fontsize = '25')
plt.title('Record Section Z : Funny Car Q4 Heat 6', fontsize = '50') 
plt.xlabel('Distance (ft) From Start Line (FL)', fontsize = '25')
plt.ylabel('Time GMT', fontsize = '25')
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.grid()

plt.savefig('./fallClean/Figures/record_section_zFCQ4H6.png', bbox_inches='tight')
plt.show()
