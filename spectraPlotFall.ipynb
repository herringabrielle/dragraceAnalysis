# %%
import obspy
import numpy as np
import math
import cmath
import serveobspy
from obspy import UTCDateTime, read, Trace, Stream
import dragrace
import SeismogramTasks as sTasks
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import numpy as np
import matplotlib
# %matplotlib inline
import json

# %%
# FC
# Funny Car Q4 Heat 6'
stx = read("./FallClean/Corrected/FAr_FL660_2019-10-12T21:44:29Z_HNX.mseed")
sty = read("./FallClean/Corrected/FAr_FL660_2019-10-12T21:44:29Z_HNY.mseed")
stz = read("./FallClean/Corrected/FAr_FL660_2019-10-12T21:44:29Z_HNZ.mseed")

# TF Window
#x1 = 6240
#x2 = 6600

# FC Window

x1=5930
x2=6375


stx[0].data = stx[0].data[x1:x2]
stx[0].spectrogram()

sty[0].data = sty[0].data[x1:x2]
sty[0].spectrogram()

stz[0].data = stz[0].data[x1:x2]
stz[0].spectrogram()

# %%
stx = read("./FallClean/Corrected/FAr_FL660_2019-10-12T18:21:15Z_HNX.mseed") # TOP FUEL6
sty = read("./FallClean/Corrected/FAr_FL660_2019-10-12T18:21:15Z_HNY.mseed")
stz = read("./FallClean/Corrected/FAr_FL660_2019-10-12T18:21:15Z_HNZ.mseed")


x1 = 6240
x2 = 6600

stx[0].data = stx[0].data[x1:x2]
stx[0].spectrogram()

sty[0].data = sty[0].data[x1:x2]
sty[0].spectrogram()

stz[0].data = stz[0].data[x1:x2]
stz[0].spectrogram()
